# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import math
#import pylab as plt
from scipy.optimize import curve_fit
from scipy import asarray as ar,exp

path = r'../'

# %% [markdown]
# ## v1
#
# E:\CODE\BNCT_CODE\BNCT-MCNP\20201202_p-target\p-Li.omcnp

# %%
plt.figure(figsize=(10,7))

filename0 = '%sP-Li_position 0 0 0.txt'%path
data = np.loadtxt(filename0)
det1 = data[:,:2]
plt.loglog(det1[:,0],det1[:,1],label='det1')

filename0 = '%sP-Li_position 0 2 0.txt'%path
data = np.loadtxt(filename0)
det2 = data[:,:2]
plt.loglog(det2[:,0],det2[:,1],label='det2')


# plt.vlines(0.4e-6, 10e0,1e10, colors = "grey", linestyles = "-.")
# plt.vlines(10e-3, 10e0,1e10, colors = "grey", linestyles = "-.")

plt.ylim((10e-13,10e-5))
plt.xlim((10e-5,3.5))
plt.legend()
plt.grid()
plt.xlabel('Energy/MeV')
plt.ylabel('Flux $n/cm^2/p$')
plt.title('BNCT-BSA')
plt.savefig('BNCT-BSA-3p5MeVproton')
plt.show()

# %% [markdown]
# ## v2
#
# E:\CODE\BNCT_CODE\BNCT-MCNP\20201202_p-target\p-Li_v2.omcnp

# %%
plt.figure(figsize=(10,7))

filename0 = '%sP-Li_position 0 0 0_v2.txt'%path
data = np.loadtxt(filename0)
det1 = data[:,:2]
plt.loglog(det1[:,0],det1[:,1],label='det1')

filename0 = '%sP-Li_position 0 2 0_v2.txt'%path
data = np.loadtxt(filename0)
det2 = data[:,:2]
plt.loglog(det2[:,0],det2[:,1],label='det2')

filename0 = '%sP-Li_position 0 1p4 1p4_v2.txt'%path
data = np.loadtxt(filename0)
det3 = data[:,:2]
plt.loglog(det3[:,0],det3[:,1],label='det3')


# plt.vlines(0.4e-6, 10e0,1e10, colors = "grey", linestyles = "-.")
# plt.vlines(10e-3, 10e0,1e10, colors = "grey", linestyles = "-.")

plt.ylim((10e-13,10e-5))
plt.xlim((10e-5,3.5))
plt.legend()
plt.grid()
plt.xlabel('Energy/MeV')
plt.ylabel('Flux $n/cm^2/p$')
plt.title('BNCT-BSA')
plt.savefig('BNCT-BSA-3p5MeVproton')
plt.show()
